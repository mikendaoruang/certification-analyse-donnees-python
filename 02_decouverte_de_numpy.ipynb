# %% [markdown]
# # Découverte de Numpy

# %% [markdown]
# ## Introduction à Numpy

# %%
list_of_list = [["Paris",75], ["Lyon", 69]]

# %% [raw]
# Avantages des listes python:
#     - peuvent contenir différents types de données
#     - puevent rétrécir et grandir dynamiquement

# %%
list = [1, "film", 3]

# %%
list.append("série")
print(list)
# Out:
# [1, 'film', 3, 'série']

# %% [raw]
# Inconvénients des listes python:
#     - consomment beaucoup d'énergie
#     - problématiques pour des datasets de moyenne à très grande taille

# %% [markdown]
# ## Les tableaux avec Numpy

# %% [markdown]
# ndarray

# %%
import numpy as np

# %%
vector = np.array([3, 4, 17, 65])

# %%
print(vector)
# Out:
# [ 3  4 17 65]

# %%
matrix = np.array([[2, 5, 15], [20, 50, 30], [34, 99, 45]])

# %%
print(matrix)
# Out:
# [[ 2  5 15]
#  [20 50 30]
#  [34 99 45]]

# %% [markdown]
# ### Exercice

# %% [raw]
# - Créer un vecteur depuis la liste [10, 20, 30]
#     - Assigner le résultat à la variable vector
# - Créer une matrice depuis la liste de listes suivante: [[50, 10, 15], [20, 25, 30], [35, 40, 45]]
#     - Assigner le résultat à la variable matrix

# %%
import numpy as np 
vector = np.array([10, 20, 30])
matrix = np.array([[50, 10, 15], [20, 25, 30], [35, 40, 45]])

# %%
print(vector)
# Out:
# [10 20 30]

# %%
print(matrix)
# Out:
# [[50 10 15]
#  [20 25 30]
#  [35 40 45]]

# %% [markdown]
# ## Taille d'un tableau

# %%
np.array(["1986", "Western Pacific", "Viet Nam", "Wine", "0"])
# Out:
# array(['1986', 'Western Pacific', 'Viet Nam', 'Wine', '0'], dtype='<U15')

# %%
np.array([["1986", "Western Pacific", "Viet Nam", "Wine", "0"], ["1986", "Americas", "Uruguay", "Other", "0.5"], ["1985", "Africa", "Ghana", "Wine", "1.62"]])
# Out:
# array([['1986', 'Western Pacific', 'Viet Nam', 'Wine', '0'],
#        ['1986', 'Americas', 'Uruguay', 'Other', '0.5'],
#        ['1985', 'Africa', 'Ghana', 'Wine', '1.62']], dtype='<U15')

# %% [markdown]
# ndarray.shape

# %%
vector = np.array([1, 2, 3, 4])
print(vector.shape)
# Out:
# (4,)

# %% [raw]
# 4 lignes, 1 colonne

# %%
matrix = np.array([[5, 10, 15], [20, 25, 30]])
print(matrix.shape)
# Out:
# (2, 3)

# %% [raw]
# 2 lignes, 3 colonnes

# %% [markdown]
# ### Exercice

# %%
import numpy as np 
vector = np.array([10, 20, 30])
matrix = np.array([[5, 10, 15], [20, 25, 30], [35, 40, 45]])

# %%
print(vector.shape)
# Out:
# (3,)

# %%
print(matrix.shape)
# Out:
# (3, 3)

# %% [markdown]
# ## Lire un dataset avec Numpy

# %%
# fonction numpy pour lire un dataset: numpy.genfromtxt()

# %%
import numpy as np
test = np.genfromtxt("data.csv"), delimiter=",")

# %% [markdown]
# ### Exercice

# %%
# Lire un dataset numpy.genfromtxt()

# %%
import numpy as np

world_alcohol = np.genfromtxt("world_alcohol.csv", delimiter=",")
print(type(world_alcohol))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Les types de données avec Numpy

# %%
# bool --> True ou False

# %%
# int --> integer

# %%
# float

# %%
# string

# %%
numbers = np.array([1, 2, 3, 4])

# %%
numbers.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Exercice

# %% [raw]
# - Assigner le type de données de world_alcohol à la variable world_alcohol_dtype
# - Afficher world_alcohol_dtype

# %%
#world_alcohol_dtype = world_alcohol.dtype
#print(world_alcohol_dtype)

# %%
#float64

# %% [markdown]
# ## Afficher les données correctement

# %%
world_alcohol = np.genfromtxt("world_alcohol.csv", delimiter=",", dtype="U75", skip_header=1)
world_alcohol
# Out:
# array([['1986', 'Western Pacific', 'Viet Nam', 'Wine', '0'],
#        ['1986', 'Americas', 'Uruguay', 'Other', '0.5'],
#        ['1985', 'Africa', "Cte d'Ivoire", 'Wine', '1.62'],
#        ...,
#        ['1986', 'Europe', 'Switzerland', 'Spirits', '2.54'],
#        ['1987', 'Western Pacific', 'Papua New Guinea', 'Other', '0'],
#        ['1986', 'Africa', 'Swaziland', 'Other', '5.15']], dtype='<U75')

# %% [markdown]
# ## Extraire une valeur depuis un tableau Numpy

# %%
vector = np.array([1, 2, 3, 4])
print(vector[0])
# Out:
# 1

# %%
list_of_list = [[5, 10, 15], [20, 25, 30]]

# %%
first_row = list_of_list[0]

# %%
first_row[2]
# Out:
# 15

# %%
# Autre méthode

# %%
list_of_list[0][2]
# Out:
# 15

# %%
matrix = np.array([[5, 10, 15], [20, 25, 30]])

# %%
matrix[1,2]
# Out:
# 30

# %% [markdown]
# ### Exercice

# %% [raw]
# - Assigner le nombre de litres de vin bu par un Ivoirien en 1985 à la variable ivoire_1985. Cela correspond à la donnée de la 3e ligne.
# - Assigner le nom du pays de la 2e ligne à la variable second_country.

# %%
ivoire_1985 = world_alcohol[2,4]
print(ivoire_1985)
# Out:
# 1.62

# %%
second_country = world_alcohol[1,2]
print(second_country)
# Out:
# Uruguay

# %% [markdown]
# ## Extraire un vecteur de valeurs depuis un tableau Numpy

# %%
vector = np.array ([1, 2, 3, 4, 5])

# %%
vector[0:3]
# Out:
# array([1, 2, 3])

# %%
matrix = np.array ([[1, 2, 3], [16, 15, 20], [25, 26, 27]])

# %%
matrix
# Out:
# array([[ 1,  2,  3],
#        [16, 15, 20],
#        [25, 26, 27]])

# %%
matrix[:,1]
# Out:
# array([ 2, 15, 26])

# %%
# Explication matrix 
# : toutes les lignes 
# ,1 deuxiéme valeur des colonnes

# %%
matrix[2,:]
# Out:
# array([25, 26, 27])

# %%
# 1:3 = commence de 15 jusqu'a 26
# ,1 = colonne du milieu

# %%
matrix[1:3,1]
# Out:
# array([15, 26])

# %% [markdown]
# ### Exercice

# %% [raw]
# - Assigner toute la 3e colonne de world_alcohol à la variable countries
# - Assigner l'ensemble de la 5e colonne de world_alcohol à la variable alcohol_consumption

# %%
countries = world_alcohol[:,2]
print(countries)
# Out:
# ['Viet Nam' 'Uruguay' "Cte d'Ivoire" ... 'Switzerland' 'Papua New Guinea'
#  'Swaziland']

# %%
alcohol_consumption = world_alcohol[:,4]
print(alcohol_consumption)
# Out:
# ['0' '0.5' '1.62' ... '2.54' '0' '5.15']

# %% [markdown]
# ## Extraire un tableau de valeurs depuis un tableau Numpy

# %%
matrix
# Out:
# array([[ 1,  2,  3],
#        [16, 15, 20],
#        [25, 26, 27]])

# %%
# :,0:2 = Toutes les valeurs des deux premieres colonnes

# %%
matrix[:,0:2]
# Out:
# array([[ 1,  2],
#        [16, 15],
#        [25, 26]])

# %%
# 1:3,: = Toutes les valeurs des deux premieres lignes

# %%
matrix[1:3,:]
# Out:
# array([[16, 15, 20],
#        [25, 26, 27]])

# %%
# [1:3,0:2]= Les deux valeurs des deux dernières lignes et Les deux valeurs des deux premières colonnes

# %%
matrix[1:3,0:2]
# Out:
# array([[16, 15],
#        [25, 26]])

# %% [markdown]
# ### Exercice

# %% [raw]
# - Assigner toutes les lignes des 2 premières colonnes de world_alcohol à la variable first_two_columns
# - Assigner les 10 premières lignes de la première colonne de world_alcohol à la variable first_ten_years
# - Assigner les 10 premières lignes de toutes les colonnes de world_alcohol à la variable first_ten_rows
# - Assigner les 20 premières lignes des colonnes d'indice 1 et 2 de world_alcohol à la variable first_twenty_regions

# %%
first_two_columns = world_alcohol[:,0:2]
print(first_two_columns)
# Out:
# [['1986' 'Western Pacific']
#  ['1986' 'Americas']
#  ['1985' 'Africa']
#  ...
#  ['1986' 'Europe']
#  ['1987' 'Western Pacific']
#  ['1986' 'Africa']]

# %%
first_ten_years = world_alcohol[0:10,0:1]
print(first_ten_years)
# Out:
# [['1986']
#  ['1986']
#  ['1985']
#  ['1986']
#  ['1987']
#  ['1987']
#  ['1987']
#  ['1985']
#  ['1986']
#  ['1984']]

# %%
first_ten_rows = world_alcohol[0:10,:]
print(first_ten_rows)
# Out:
# [['1986' 'Western Pacific' 'Viet Nam' 'Wine' '0']
#  ['1986' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1985' 'Africa' "Cte d'Ivoire" 'Wine' '1.62']
#  ['1986' 'Americas' 'Colombia' 'Beer' '4.27']
#  ['1987' 'Americas' 'Saint Kitts and Nevis' 'Beer' '1.98']
#  ['1987' 'Americas' 'Guatemala' 'Other' '0']
#  ['1987' 'Africa' 'Mauritius' 'Wine' '0.13']
#  ['1985' 'Africa' 'Angola' 'Spirits' '0.39']
#  ['1986' 'Americas' 'Antigua and Barbuda' 'Spirits' '1.55']
#  ['1984' 'Africa' 'Nigeria' 'Other' '6.1']]

# %%
first_twenty_regions = world_alcohol[0:20,1:3]
print(first_twenty_regions)
# Out:
# [['Western Pacific' 'Viet Nam']
#  ['Americas' 'Uruguay']
#  ['Africa' "Cte d'Ivoire"]
#  ['Americas' 'Colombia']
#  ['Americas' 'Saint Kitts and Nevis']
#  ['Americas' 'Guatemala']
#  ['Africa' 'Mauritius']
#  ['Africa' 'Angola']
#  ['Americas' 'Antigua and Barbuda']
#  ['Africa' 'Nigeria']
#  ['Africa' 'Botswana']
#  ['Americas' 'Guatemala']
#  ['Western Pacific' "Lao People's Democratic Republic"]
#  ['Eastern Mediterranean' 'Afghanistan']
#  ['Western Pacific' 'Viet Nam']
#  ['Africa' 'Guinea-Bissau']
#  ['Americas' 'Costa Rica']
#  ['Africa' 'Seychelles']
#  ['Europe' 'Norway']
#  ['Africa' 'Kenya']]
